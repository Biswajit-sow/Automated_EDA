# %%
# !pip install dtale
# Out:
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ---------------------------------------- 642.7/642.7 kB 8.3 MB/s  0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ---------------------------------------- 0.0/17.6 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/17.6 MB 7.4 MB/s eta 0:00:03
#    ------ --------------------------------- 2.9/17.6 MB 7.0 MB/s eta 0:00:03
#    --------- ------------------------------ 4.2/17.6 MB 7.0 MB/s eta 0:00:02
#    ------------- -------------------------- 5.8/17.6 MB 7.0 MB/s eta 0:00:02
#    -------------- ------------------------- 6.3/17.6 MB 6.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.6/17.6 MB 6.2 MB/s eta 0:00:02
#    -------------------- ------------------- 8.9/17.6 MB 6.1 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import dtale

# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://0.0.0.0:40000/dtale/iframe/3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
